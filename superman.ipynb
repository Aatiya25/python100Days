# %% [markdown]
# <a href="https://colab.research.google.com/github/Aatiya25/python100Days/blob/master/superman.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### SUPERMAN

import matplotlib.pyplot as plt
import numpy as np
from numpy import inf
import math
#Equation1
Y= np.arange(-12,12)
X= np.zeros((0))
for y in Y:
  X=np.append(X,9)

#Equation2
Y1 = (np.arange(-18,-12,.01), np.arange(12,18,.01))
X1 = np.zeros((0))

for y in Y1:
  X1 = np.append(X1, -(abs(y))+21)
X = np.append(X,X1)
Y = np.append(Y, Y1)



#---Equation3---
Y1= np.arange(-18,18,0.005)
X1= np.zeros((0))

for y in Y1:
  X1=np.append(X1, abs(y)-15)
X = np.append(X,X1)
Y = np.append(Y,Y1) 

#Equation4
Y1= np.append(np.arange(-11,-8,0.01),np.arange(-1,0,0.01))
X1= np.zeros((0))

for y in Y1:
  X1=np.append(X1,7)
X = np.append(X,X1)
Y = np.append(Y,Y1) 

#4b
Y1= np.arange(7,9,0.01)
X1= np.zeros((0))

for y in Y1:
  X1=np.append(X1,7)
X = np.append(X,X1)
Y = np.append(Y,Y1) 

##5----
Y1= np.append(np.arange(-15,-11,0.01),np.arange(12,15,0.01))
X1= np.zeros((0))
for y in Y1:
  X1=np.append(X1,(-abs(y))+18)
X = np.append(X,X1)
Y = np.append(Y,Y1) 

##----6a-----
Y1= np.append(np.arange(-15,-13,0.01),np.arange(-9,-6,0.01))
X1= np.zeros((0))

for y in Y1:
  X1=np.append(X1,abs(y)-12)
X = np.append(X,X1)
Y = np.append(Y,Y1) 


##----6b-----
Y1= np.append(np.arange(-4,4,0.01),np.arange(11,15,0.01))
X1= np.zeros((0))

for y in Y1:
  X1=np.append(X1,abs(y)-12)
X = np.append(X,X1)
Y = np.append(Y,Y1) 

##----7-----
Y1= np.arange(0,6,0.01)
X1= np.zeros((0))

for y in Y1:
  X1=np.append(X1,-((0.33*y)**2)+7)
X = np.append(X,X1)
Y = np.append(Y,Y1)


##----8-----
Y1= np.arange(6,12,0.01)
X1= np.zeros((0))

for y in Y1:
  X1=np.append(X1,3)
X = np.append(X,X1)
Y = np.append(Y,Y1) 


#----9-----
X1= np.arange(3,6,0.01)
Y1= np.zeros((0))

for x in X1:
  Y1=np.append(12,Y1)
X = np.append(X,X1)
Y = np.append(Y,Y1) 


#---10----

Y1= np.arange(-5,0,0.01)
X1= np.zeros((0))

for y in Y1:
  X1=np.append(X1,(math.sqrt(y+5))+5)
X = np.append(X,X1)
Y = np.append(Y,Y1)
 

 #---11----

Y1= np.arange(-4,4,.05)
X1= np.zeros((0))

for y in Y1:
  X1=np.append(X1,((0.25*y)**2)-9)
X = np.append(X,X1)
Y = np.append(Y,Y1)
 
 #------12 -------
Y1= np.arange(7,8,0.01)
X1= np.zeros((0))

for y in Y1:
  X1=np.append(X1,((math.sqrt(-(y-8)))*2)+5)

X = np.append(X,X1)
Y = np.append(Y,Y1)

#----13
Y1= np.arange(8,9,0.01)
X1= np.zeros((0))

for y in Y1:
  X1=np.append(X1,(2*y)-11)

X = np.append(X,X1)
Y = np.append(Y,Y1)


 #----14 ----
Y1= np.arange(-13,-8,0.05)
X1= np.zeros((0))

for y in Y1:
  X1=np.append(X1,(6*(math.sqrt(0.2*(y+13))))+1)

X = np.append(X,X1)
Y = np.append(Y,Y1)

#---15
Y1= np.arange(-6,0)
X1= np.zeros((0))

for y in Y1:
  X1=np.append(X1,-((0.33*(y+3))**2)-5)
-((0.33*(y+3))**2)-5
X = np.append(X,X1)
Y = np.append(Y,Y1)

#----16
Y1= np.arange(-9,0,0.01)
X1= np.zeros((0))

for y in Y1:
  X1=np.append(X1,((0.125*(y+1))**2)-4)
X = np.append(X,X1)
Y = np.append(Y,Y1)

#17----
Y1= np.arange(-1,0,0.01)
X1= np.zeros((0))

for y in Y1:
  X1=np.append(X1,-4)
X = np.append(X,X1)
Y = np.append(Y,Y1)

###18
Y1= np.arange(0,5,0.01)
X1= np.zeros((0))

for y in Y1:
  X1=np.append(X1,math.sqrt(-(0.167*(y-6)))-5)
  
X = np.append(X,X1)
Y = np.append(Y,Y1)

###19
Y1= np.arange(0,5,0.01)
X1= np.zeros((0))

for y in Y1:
  X1=np.append(X1,-math.sqrt(-(0.167*(y-6)))-5)
  
X = np.append(X,X1)
Y = np.append(Y,Y1)


##20---
Y1= np.arange(-5,0,0.01)
X1= np.zeros((0))

for y in Y1:
  X1=np.append(X1,-0.6*(math.sqrt(5*(y+5)))+5)
  
X = np.append(X,X1)
Y = np.append(Y,Y1)

##21---
Y1= np.arange(0,11,0.01)
X1= np.zeros((0))

for y in Y1:
  X1=np.append(X1,0.6*(math.sqrt(-2.27*(y-11)))-1)
  
X = np.append(X,X1)
Y = np.append(Y,Y1)

plt.plot(Y,X,'yo')

#plt.grid()
plt.show()

# %%
ax = plt.gca()
ax.set_facecolor('xkcd:white')

plt.plot(Y,X, 'ro')
ax.set_yticklabels([])
ax.set_xticklabels([])
plt.show()

# %%
8
